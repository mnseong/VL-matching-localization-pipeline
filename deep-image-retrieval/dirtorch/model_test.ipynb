# %%
import sys
sys.path.append('/home/minseong/.pyenv/versions/3.8.17/envs/vl-pipeline/lib/python3.8/site-packages')
sys.path
# Out:
# ['/mnt/hdd4T/minseong/github/VL-matching-localization-pipeline/deep-image-retrieval/dirtorch',
#  '/usr/lib/python38.zip',
#  '/usr/lib/python3.8',
#  '/usr/lib/python3.8/lib-dynload',
#  '',
#  '/home/minseong/.local/lib/python3.8/site-packages',
#  '/usr/local/lib/python3.8/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/home/minseong/.pyenv/versions/3.8.17/envs/vl-pipeline/lib/python3.8/site-packages']

# %%
import torch
import torchsummary
from nets import resnet101_rmac

# %%
model = resnet101_rmac()
model
# Out:
# ResNet_RMAC(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %%
ck_point = torch.load("models/Resnet101-AP-GeM-LM18.pt")
# Out:
# /home/minseong/.local/lib/python3.8/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.decomposition.pca module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.decomposition. Anything that cannot be imported from sklearn.decomposition is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/minseong/.local/lib/python3.8/site-packages/sklearn/base.py:313: UserWarning: Trying to unpickle estimator PCA from version 0.20.2 when using version 0.22. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
ck_point
# Out:
# {'arch': 'resnet101_rmac',
# ...

# %%
model = resnet101_rmac()

# %%
model.load_state_dict(ck_point['state_dict'])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model.load_state_dict(ck_point['state_dict'])
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:2150, in Module.load_state_dict(self, state_dict, strict, assign)
#    2145         error_msgs.insert(
#    2146             0, 'Missing key(s) in state_dict: {}. '.format(
#    2147                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    2149 if len(error_msgs) > 0:
# -> 2150     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2151                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2152 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for ResNet_RMAC:
# ...
